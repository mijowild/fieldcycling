# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import src.stelardatafile as sdf

# %%
polymer=sdf.StelarDataFile('297K.sdf',r'data')
polymer.sdfimport()
datas = polymer.datas
# Out:
# escape
# 145 experiments read

# %%
data = datas[1][1]
paras = datas[1][0]
a_arr = np.array(data)
df = pd.DataFrame(data=a_arr, columns=['d1', 'd2'])

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
